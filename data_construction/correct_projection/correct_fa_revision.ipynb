# %%
import csv
import json
from copy import deepcopy
import ast
csv.field_size_limit(1131072)
# Out:
# 1131072

# %%
def remove_drop_words(alignment):
    result = set()
    for start, end in alignment:
        result.add((start, end//2))
    return result

def extract_pair(result):
    starts = set()
    ends = set()
    for start, end in result:
        starts.add(start)
        ends.add(end)
    start_idx = min(list(starts))
    end_idx = max(list(ends))
    return [min(list(ends)), max(list(ends))+1]

def extract_alignment_pair_original(alignment):
    result = set()
    for s in range(len(alignment)):
        for t in range(len(alignment[0])):
            if alignment[s][t]:
                result.add((s, t))
    return sorted(list(result))

def extract_alignment_pair_space(alignment):
    result = set()
    for s in range(len(alignment)):
        for t in range(len(alignment[0])):
            if alignment[s][t]:
                result.add((s, t))
    return sorted(list(remove_drop_words(result)))

# %%
source_data = []
with open('data/fa_test/source/to_tasa_all_fa_test_with_id.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for item in reader:
        source_data.append(item)

# %%
print(len(source_data))
print(source_data[0].keys())
print(source_data[0])
# Out:
# 7704
# dict_keys(['src_tokens', 'tar_tokens', 'config_obj', 'mention_id'])
# {'src_tokens': '[\'There\', \'you\', \'go\', \'.\', \'You\', "\'re", \'all\', \'done\', \'!\']', 'tar_tokens': "['ردیف', 'شد']", 'config_obj': '{"src_enable_retokenize": false, "version": {"PATCH": 0, "MAJOR": 1, "MINOR": 0}, "tar_enable_retokenize": false,"src_head_inds":[0],"alignment":[[true, false], [false, false], [false, false], [false, false], [false, false], [false, false], [false, false], [false, false], [false, false]]}', 'mention_id': 's09e03c09t|0'}

# %%
source_inputs = []
for set_key in ["0_1000", "1000_2000", "2000_3000", "3000_4000","4000_5000", "5000_6000","6000_7000", "7000_end"]:
    with open('data/fa_test/inputs/to_tasa_fa_drop_test_set_'+set_key+'.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for item in reader:
            source_inputs.append(item)

# %%
print(len(source_inputs))
print(source_inputs[0].keys())
print(source_inputs[0])
# Out:
# 7704
# dict_keys(['src_tokens', 'tar_tokens', 'config_obj'])
# {'src_tokens': '[\'There\', \'you\', \'go\', \'.\', \'You\', "\'re", \'all\', \'done\', \'!\']', 'tar_tokens': '["\\u0631\\u062f\\u06cc\\u0641", "", "\\u0634\\u062f", ""]', 'config_obj': '{"src_enable_retokenize": false, "version": {"PATCH": 0, "MAJOR": 1, "MINOR": 0}, "tar_enable_retokenize": false,"src_head_inds":[0],"alignment":[[true, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false]]}'}

# %%
coe_annotations = []
# Batch 0: first 400
for split_name in ["batch_0_0_448"]:
    with open('data/fa_test/annotations/'+split_name+'.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for i, item in enumerate(reader):
            if i>=400:
                continue
            coe_annotations.append(item)
# Batch 0: later 600
for split_name in ["batch_0_400_1000"]:
    with open('data/fa_test/annotations/'+split_name+'.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for item in reader:
            coe_annotations.append(item)

for split_name in ["batch_1", "batch_2","batch_3","batch_4","batch_5","batch_6", "batch_7"]:
    with open('data/fa_test/annotations/'+split_name+'.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for item in reader:
            coe_annotations.append(item)

# %%
# coe_annotations = []
# # for split_name in ["batch_0_0_448"]:
# for split_name in ["batch_0_400_1000"]:
#     with open('data/fa/annotations/'+split_name+'.csv', 'r', encoding='utf-8') as f:
#         reader = csv.DictReader(f)
#         for item in reader:
#             coe_annotations.append(item)

# %%
all_data = {}
with open('data/fa_test/source/all_coref_data_en_finalized.json', 'r') as f:
    temp = json.load(f)
    for item in temp:
        all_data[item['scene_id']] = item

mention_dict = {}
for item in all_data:
    annotations = all_data[item]['annotations']
    for anno in annotations:
        query = anno['query']
        antecedents = anno['antecedents']
        mention_dict[query['mention_id']] = [query['sentenceIndex'], query['startToken'],query['endToken']]
        if antecedents!=[]:
            if isinstance(antecedents[0], dict):
                for ante in antecedents:
                    mention_dict[ante['mention_id']] = [ante['sentenceIndex'], ante['startToken'],ante['endToken']]

# %%
all_data_fa = {}
with open('data/fa_test/source/all_coref_data_en_fa_finalized.json', 'r') as f:
    temp = json.load(f)
    for item in temp:
        all_data_fa[item['scene_id']] = item

mention_dict_fa = {}
for item in all_data_fa:
    annotations = all_data_fa[item]['annotations']
    for anno in annotations:
        query = anno['query']
        antecedents = anno['antecedents']
        mention_dict_fa[query['mention_id']] = [query['sentenceIndex'], query['startToken'],query['endToken']]
        if antecedents!=[]:
            if isinstance(antecedents[0], dict):
                for ante in antecedents:
                    mention_dict_fa[ante['mention_id']] = [ante['sentenceIndex'], ante['startToken'],ante['endToken']]

# %%
print(ast.literal_eval(coe_annotations[1]['Input.src_tokens']))
print(type(ast.literal_eval(coe_annotations[1]['Input.src_tokens'])))
# Out:
# ['There', 'you', 'go', '.', 'You', "'re", 'all', 'done', '!']
# <class 'list'>

# %%
num_corrected = 0
num_add = 0
num_delete = 0
num_modify = 0
drop_add_num = 0
drop_delete_num = 0
drop_modify_num = 0

correction_dict = {}
remove_set = set()
add_dict = {}

all_correction_lines = []

# for i in range(len(coe_annotations)):
count = 0
# for i in range(6400):
for i in range(len(coe_annotations)):
    # extract_alignment_pair_original(json.loads(source_data[i]['config_obj'])['alignment'])
    # extract_alignment_pair_space(json.loads(source_inputs[i]['config_obj'])['alignment'])

    # if source_data[i]['mention_id'] in mention_dict_fa:
    #     temp_0 = extract_pair(extract_alignment_pair_original(json.loads(source_data[i]['config_obj'])['alignment']))
    #     temp_1 = extract_pair(extract_alignment_pair_space(json.loads(source_inputs[i]['config_obj'])['alignment']))
    #     sent_id, start, end = mention_dict_fa[source_data[i]['mention_id']]
    #     mention_text_source = "".join(ast.literal_eval(source_data[i]['tar_tokens'])[temp_0[0]: temp_0[1]])
    #     mention_text_tasa = "".join(all_data_fa[source_data[i]['mention_id'][:10]]['sentences'][sent_id][start: end])
    #     print(source_data[i]['mention_id'], source_data[i]['mention_id'][:10], [sent_id, start, end], temp_0, temp_1)
    #     print(mention_text_source==mention_text_tasa, mention_text_source, mention_text_tasa)
    #     print("".join(all_data_fa[source_data[i]['mention_id'][:10]]['sentences'][sent_id]))
    #     # print(extract_alignment_pair_original(json.loads(source_data[i]['config_obj'])['alignment']))
    #     # print(extract_alignment_pair_space(json.loads(source_inputs[i]['config_obj'])['alignment']))
    #     print()
    #     # if mention_text_source!=mention_text_tasa:
    #     #     print(mention_text_source==mention_text_tasa, mention_text_source, mention_text_tasa)
    #     # # print()

    original_result = extract_alignment_pair_space(json.loads(coe_annotations[i]['Input.config_obj'])['alignment'])
    corrected_result = extract_alignment_pair_space(json.loads(coe_annotations[i]['Answer.alignment']))

    original_result_with_drop = extract_alignment_pair_original(json.loads(coe_annotations[i]['Input.config_obj'])['alignment'])
    corrected_result_with_drop = extract_alignment_pair_original(json.loads(coe_annotations[i]['Answer.alignment']))
    if original_result==corrected_result:
        continue
    mention_id = source_data[i]['mention_id']

    a = ()
    b = ()
    c = ()
    if original_result!=[]:
        a = extract_pair(original_result)
    if corrected_result!=[]:
        b = extract_pair(corrected_result)
    if mention_id in mention_dict_fa:
        c = [mention_dict_fa[mention_id][1], mention_dict_fa[mention_id][2]]
    # print(a==c, mention_id, a, c, b)

    # sentence = ast.literal_eval(coe_annotations[i]['Input.tar_tokens'])
    sentence = ast.literal_eval(source_data[i]['tar_tokens'])
    original_text = ""
    corrected_text = ""
    if a!=():
        original_text = " ".join(sentence[a[0]: a[1]])
    if b!=():
        corrected_text = " ".join(sentence[b[0]: b[1]])
    # print(mention_id)
    # print("Original Mention Index:", a, original_text)
    # print("Corrected Mention Index:", b, corrected_text)
    # count += 1
    # if a==() and b!=():
    #     print("Add")
    #     count += 1
    # if a!=() and b==():
    #     print("Delete")
    #     # count += 1

    if a==() and b!=():
        num_add += 1
        if len(corrected_result_with_drop)==1 and corrected_result_with_drop[0][1]%2==0:
            drop_add_num += 1
            print(corrected_result)
            print(corrected_result_with_drop)
            print(mention_id)
            print("Original Mention Index:", a, original_text)
            print("Corrected Mention Index:", b, corrected_text)
            print()
    if a!=() and b==():
        num_delete += 1
        if len(corrected_result_with_drop)==1 and corrected_result_with_drop[0][1]%2==0:
            drop_delete_num += 1
            # print(corrected_result)
            # print(corrected_result_with_drop)
            # print()
    if a!=() and b!=():
        num_modify += 1
        if len(corrected_result_with_drop)==1 and corrected_result_with_drop[0][1]%2==0:
            drop_modify_num += 1
            # print(corrected_result)
            # print(corrected_result_with_drop)
            # print()

    all_correction_lines.append([
        mention_id,
        a,
        b,
        original_text,
        corrected_text
    ])
    # print(source_data[i]['mention_id'], a, b)
    # print(mention_dict[mention_id], a)
    # print()

    # if source_data[i]['mention_id'] in mention_dict:
    #     mention_id = source_data[i]['mention_id']
    #     target = mention_dict[source_data[i]['mention_id']][1:]
    #     correction_dict[mention_id] = [a, b]
    if b==(): # Add mention_id to remove set
        remove_set.add(source_data[i]['mention_id'])
    elif a==(): # Collect mentions to add
        add_dict[source_data[i]['mention_id']] = [mention_dict[mention_id][0], b[0], b[1]]
    else:
        correction_dict[source_data[i]['mention_id']] = [mention_dict[mention_id][0], b[0], b[1]]
# Out:
# [(11, 14)]
# [(11, 28)]
# s09e04c09t|15
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] تو
#
# [(26, 36)]
# [(26, 72)]
# s09e04c09t|21
# Original Mention Index: ()
# Corrected Mention Index: [36, 37] شدم
#
# [(0, 0)]
# [(0, 0)]
# s09e04c09t|24
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونم
#
# [(0, 7)]
# [(0, 14)]
# s09e04c09t|57
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] نمیزنن
#
# [(0, 3)]
# [(0, 6)]
# s09e04c09t|60
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] میزنن
#
# [(2, 6)]
# [(2, 12)]
# s09e04c09t|64
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] نمیزنن
#
# [(11, 16)]
# [(11, 32)]
# s09e04c10t|17
# Original Mention Index: ()
# Corrected Mention Index: [16, 17] نتونستم
#
# [(72, 60)]
# [(72, 120)]
# s09e04c12t|58
# Original Mention Index: ()
# Corrected Mention Index: [60, 61] کرده
#
# [(22, 19)]
# [(22, 38)]
# s09e04c12t|78
# Original Mention Index: ()
# Corrected Mention Index: [19, 20] بذاریم
#
# [(15, 9)]
# [(15, 18)]
# s09e04c12t|100
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] بخوای
#
# [(7, 3)]
# [(7, 6)]
# s09e04c12t|119
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] براتون
#
# [(12, 10)]
# [(12, 20)]
# s09e04c12t|122
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] میترسم
#
# [(27, 18)]
# [(27, 36)]
# s09e04c12t|127
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] میخوابیم
#
# [(1, 5)]
# [(1, 10)]
# s09e07c00t|0
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] شنیدین
#
# [(8, 11)]
# [(8, 22)]
# s09e07c00t|13
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] بودم
#
# [(19, 18)]
# [(19, 36)]
# s09e07c00t|25
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] میدونستم
#
# [(21, 18)]
# [(21, 36)]
# s09e07c00t|27
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] میدونستم
#
# [(3, 11)]
# [(3, 22)]
# s09e07c00t|40
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] شدی
#
# [(7, 2)]
# [(7, 4)]
# s09e07c00t|87
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] تو
#
# [(1, 2)]
# [(1, 4)]
# s09e07c01t|2
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] داری
#
# [(0, 0)]
# [(0, 0)]
# s09e07c01t|22
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونم
#
# [(8, 8)]
# [(8, 16)]
# s09e07c01t|53
# Original Mention Index: ()
# Corrected Mention Index: [8, 9] دارم
#
# [(12, 7)]
# [(12, 14)]
# s09e07c02t|8
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] میدونم
#
# [(21, 15)]
# [(21, 30)]
# s09e07c02t|13
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] میذارم
#
# [(27, 17)]
# [(27, 34)]
# s09e07c02t|16
# Original Mention Index: ()
# Corrected Mention Index: [17, 18] گفتم
#
# [(51, 38)]
# [(51, 76)]
# s09e07c02t|26
# Original Mention Index: ()
# Corrected Mention Index: [38, 39] صداش
#
# [(58, 46)]
# [(58, 92)]
# s09e07c02t|30
# Original Mention Index: ()
# Corrected Mention Index: [46, 47] میخوام
#
# [(74, 61)]
# [(74, 122)]
# s09e07c02t|34
# Original Mention Index: ()
# Corrected Mention Index: [61, 62] میشنویش
#
# [(77, 61)]
# [(77, 122)]
# s09e07c02t|36
# Original Mention Index: ()
# Corrected Mention Index: [61, 62] میشنویش
#
# [(83, 62)]
# [(83, 124)]
# s09e07c02t|39
# Original Mention Index: ()
# Corrected Mention Index: [62, 63] میدونی
#
# [(10, 10)]
# [(10, 20)]
# s09e07c02t|62
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] میشنومش
#
# [(0, 2)]
# [(0, 4)]
# s09e07c02t|94
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] بودم
#
# [(4, 9)]
# [(4, 18)]
# s09e07c03t|14
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] میکردم
#
# [(0, 0)]
# [(0, 0)]
# s09e07c03t|42
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میخوام
#
# [(15, 13)]
# [(15, 26)]
# s09e07c03t|60
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] که
#
# [(3, 4)]
# [(3, 8)]
# s09e07c04t|0
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] میخوایم
#
# [(3, 4)]
# [(3, 8)]
# s09e07c04t|12
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] میشناسی
#
# [(10, 13)]
# [(10, 26)]
# s09e07c04t|42
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] دیدم
#
# [(55, 42)]
# [(55, 84)]
# s09e07c04t|57
# Original Mention Index: ()
# Corrected Mention Index: [42, 43] شدم
#
# [(34, 35)]
# [(34, 70)]
# s09e07c04t|84
# Original Mention Index: ()
# Corrected Mention Index: [35, 36] میدونین
#
# [(0, 2)]
# [(0, 4)]
# s09e07c04t|131
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] دارم
#
# [(1, 3)]
# [(1, 6)]
# s09e07c04t|158
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] ببینیم
#
# [(0, 1)]
# [(0, 2)]
# s09e07c05t|25
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] مخوام
#
# [(7, 5)]
# [(7, 10)]
# s09e07c05t|30
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] تلاشم
#
# [(7, 9)]
# [(7, 18)]
# s09e07c05t|52
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] داره
#
# [(7, 2)]
# [(7, 4)]
# s09e07c05t|58
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میخوام
#
# [(4, 2)]
# [(4, 4)]
# s09e07c05t|61
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] نکنم
#
# [(9, 3)]
# [(9, 6)]
# s09e07c05t|63
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] بتونین
#
# [(11, 13)]
# [(11, 26)]
# s09e07c06t|4
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] کرده
#
# [(2, 2)]
# [(2, 4)]
# s09e07c06t|44
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] داری
#
# [(0, 16)]
# [(0, 32)]
# s09e07c06t|57
# Original Mention Index: ()
# Corrected Mention Index: [16, 17] داری
#
# [(8, 7)]
# [(8, 14)]
# s09e07c06t|93
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] میخواستم
#
# [(15, 12)]
# [(15, 24)]
# s09e07c06t|98
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] امی
#
# [(0, 2)]
# [(0, 4)]
# s09e07c06t|101
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] خریدی
#
# [(2, 0)]
# [(2, 0)]
# s09e07c06t|103
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] براش
#
# [(8, 3)]
# [(8, 6)]
# s09e07c06t|151
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] بتونم
#
# [(4, 0)]
# [(4, 0)]
# s09e07c06t|155
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] متاسفم
#
# [(12, 5)]
# [(12, 10)]
# s09e07c06t|162
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میدونین
#
# [(0, 0)]
# [(0, 0)]
# s09e07c06t|173
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونم
#
# [(0, 0)]
# [(0, 0)]
# s09e07c06t|176
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] گفتم
#
# [(9, 6)]
# [(9, 12)]
# s09e07c06t|224
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] فهمیدم
#
# [(30, 23)]
# [(30, 46)]
# s09e07c06t|233
# Original Mention Index: ()
# Corrected Mention Index: [23, 24] بگیرم
#
# [(0, 0)]
# [(0, 0)]
# s09e07c06t|236
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونستم
#
# [(5, 1)]
# [(5, 2)]
# s09e07c06t|240
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] بوشون
#
# [(4, 6)]
# [(4, 12)]
# s09e07c06t|243
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] بودی
#
# [(7, 3)]
# [(7, 6)]
# s09e07c06t|246
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] سالم
#
# [(21, 18)]
# [(21, 36)]
# s09e07c06t|253
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] پرسیدم
#
# [(33, 35)]
# [(33, 70)]
# s09e07c06t|260
# Original Mention Index: ()
# Corrected Mention Index: [35, 36] گرفتم
#
# [(8, 9)]
# [(8, 18)]
# s09e07c06t|277
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] هنوزم
#
# [(1, 2)]
# [(1, 4)]
# s09e07c06t|284
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] گفتم
#
# [(0, 1)]
# [(0, 2)]
# s09e07c06t|296
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میخوام
#
# [(33, 23)]
# [(33, 46)]
# s09e07c06t|320
# Original Mention Index: ()
# Corrected Mention Index: [23, 24] نداره
#
# [(39, 30)]
# [(39, 60)]
# s09e07c06t|323
# Original Mention Index: ()
# Corrected Mention Index: [30, 31] بود
#
# [(0, 1)]
# [(0, 2)]
# s09e07c06t|327
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] منظورم
#
# [(7, 6)]
# [(7, 12)]
# s09e07c06t|331
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] میکنی
#
# [(2, 0)]
# [(2, 0)]
# s09e07c06t|369
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] داری
#
# [(0, 3)]
# [(0, 6)]
# s09e07c07t|0
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] نداری
#
# [(3, 2)]
# [(3, 4)]
# s09e07c07t|19
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میدونین
#
# [(10, 6)]
# [(10, 12)]
# s09e07c07t|22
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] هستیم
#
# [(9, 3)]
# [(9, 6)]
# s09e07c07t|36
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] میدونم
#
# [(19, 17)]
# [(19, 34)]
# s09e07c07t|64
# Original Mention Index: ()
# Corrected Mention Index: [17, 18] میارم
#
# [(0, 4)]
# [(0, 8)]
# s09e07c07t|76
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] نمیدونم
#
# [(5, 10)]
# [(5, 20)]
# s09e07c07t|78
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] گفته
#
# [(6, 4)]
# [(6, 8)]
# s09e07c07t|99
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] بمیریم
#
# [(0, 0)]
# [(0, 0)]
# s09e07c08t|0
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] باورم
#
# [(0, 0)]
# [(0, 0)]
# s09e07c08t|7
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونم
#
# [(20, 16)]
# [(20, 32)]
# s09e07c08t|18
# Original Mention Index: ()
# Corrected Mention Index: [16, 17] روش
#
# [(3, 12)]
# [(3, 24)]
# s09e07c08t|27
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] میارن
#
# [(1, 0)]
# [(1, 0)]
# s09e07c08t|38
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونی
#
# [(2, 4)]
# [(2, 8)]
# s09e07c08t|46
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] اینکه
#
# [(9, 7)]
# [(9, 14)]
# s09e07c08t|47
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] امی
#
# [(19, 15)]
# [(19, 30)]
# s09e07c08t|51
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] بخوام
#
# [(0, 0)]
# [(0, 0)]
# s09e07c08t|60
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میخوام
#
# [(24, 19)]
# [(24, 38)]
# s09e07c08t|74
# Original Mention Index: ()
# Corrected Mention Index: [19, 20] کنیم
#
# [(39, 35)]
# [(39, 70)]
# s09e07c08t|83
# Original Mention Index: ()
# Corrected Mention Index: [35, 36] میتونه
#
# [(1, 1)]
# [(1, 2)]
# s09e07c09t|0
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] کنم
#
# [(15, 12)]
# [(15, 24)]
# s09e07c09t|17
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] نمیخواستم
#
# [(21, 14)]
# [(21, 28)]
# s09e07c09t|19
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] امیدش
#
# [(12, 8)]
# [(12, 16)]
# s09e07c09t|36
# Original Mention Index: ()
# Corrected Mention Index: [8, 9] نمیخوام
#
# [(19, 19)]
# [(19, 38)]
# s09e07c09t|64
# Original Mention Index: ()
# Corrected Mention Index: [19, 20] راه
#
# [(2, 2)]
# [(2, 4)]
# s09e07c09t|97
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میرم
#
# [(3, 4)]
# [(3, 8)]
# s09e07c09t|102
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] دارم
#
# [(26, 18)]
# [(26, 36)]
# s09e07c09t|110
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] داشتیم
#
# [(24, 34)]
# [(24, 68)]
# s09e07c09t|144
# Original Mention Index: ()
# Corrected Mention Index: [34, 35] میکنم
#
# [(0, 0)]
# [(0, 0)]
# s09e07c09t|156
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] مطمئنم
#
# [(3, 5)]
# [(3, 10)]
# s09e07c09t|158
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میشم
#
# [(0, 0)]
# [(0, 0)]
# s09e07c09t|162
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونم
#
# [(1, 5)]
# [(1, 10)]
# s09e09c00t|0
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] دیدید
#
# [(1, 5)]
# [(1, 10)]
# s09e09c00t|3
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] دیدید
#
# [(4, 3)]
# [(4, 6)]
# s09e09c00t|13
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] چطوری
#
# [(0, 1)]
# [(0, 2)]
# s09e09c00t|15
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میگی
#
# [(9, 9)]
# [(9, 18)]
# s09e09c00t|58
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] نیستم
#
# [(34, 26)]
# [(34, 52)]
# s09e09c00t|67
# Original Mention Index: ()
# Corrected Mention Index: [26, 27] میخوادش
#
# [(1, 1)]
# [(1, 2)]
# s09e09c00t|116
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] نمیتونیم
#
# [(0, 0)]
# [(0, 0)]
# s09e09c00t|138
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیتونم
#
# [(1, 3)]
# [(1, 6)]
# s09e09c00t|149
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] نمیتونی
#
# [(39, 34)]
# [(39, 68)]
# s09e09c01t|31
# Original Mention Index: ()
# Corrected Mention Index: [34, 35] میخوای
#
# [(26, 19)]
# [(26, 38)]
# s09e09c01t|41
# Original Mention Index: ()
# Corrected Mention Index: [19, 20] تو
#
# [(5, 4)]
# [(5, 8)]
# s09e09c01t|49
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] توهم
#
# [(20, 11)]
# [(20, 22)]
# s09e09c01t|54
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] بتونیم
#
# [(0, 1)]
# [(0, 2)]
# s09e09c01t|58
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] نمیکنی
#
# [(11, 13)]
# [(11, 26)]
# s09e09c01t|65
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] میخوام
#
# [(34, 30)]
# [(34, 60)]
# s09e09c01t|75
# Original Mention Index: ()
# Corrected Mention Index: [30, 31] نباشه
#
# [(5, 7)]
# [(5, 14)]
# s09e09c01t|85
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] زدم
#
# [(1, 0)]
# [(1, 0)]
# s09e09c01t|93
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونستی
#
# [(7, 6)]
# [(7, 12)]
# s09e09c02t|28
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] بتونم
#
# [(4, 4)]
# [(4, 8)]
# s09e09c02t|34
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] کنم
#
# [(3, 0)]
# [(3, 0)]
# s09e09c02t|41
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میتونم
#
# [(2, 2)]
# [(2, 4)]
# s09e09c02t|50
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] خوشحالم
#
# [(4, 4)]
# [(4, 8)]
# s09e09c02t|52
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] اومدید
#
# [(1, 3)]
# [(1, 6)]
# s09e09c02t|70
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] خوشحالم
#
# [(3, 0)]
# [(3, 0)]
# s09e09c02t|79
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] منو
#
# [(7, 6)]
# [(7, 12)]
# s09e09c02t|81
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] بگم
#
# [(4, 4)]
# [(4, 8)]
# s09e09c02t|95
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] داریم
#
# [(0, 1)]
# [(0, 2)]
# s09e09c03t|10
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میکنم
#
# [(3, 3)]
# [(3, 6)]
# s09e09c03t|12
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] شدم
#
# [(8, 4)]
# [(8, 8)]
# s09e09c03t|18
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] میشناسی
#
# [(27, 21)]
# [(27, 42)]
# s09e09c03t|26
# Original Mention Index: ()
# Corrected Mention Index: [21, 22] میتونی
#
# [(0, 1)]
# [(0, 2)]
# s09e09c03t|36
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] نمیده
#
# [(6, 3)]
# [(6, 6)]
# s09e09c03t|87
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] تو
#
# [(1, 5)]
# [(1, 10)]
# s09e09c04t|17
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] بود
#
# [(13, 15)]
# [(13, 30)]
# s09e09c04t|24
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] لیست
#
# [(0, 4)]
# [(0, 8)]
# s09e09c04t|44
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] برم
#
# [(4, 7)]
# [(4, 14)]
# s09e09c04t|47
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] م
#
# [(2, 1)]
# [(2, 2)]
# s09e09c04t|53
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] ت
#
# [(26, 22)]
# [(26, 44)]
# s09e09c05t|9
# Original Mention Index: ()
# Corrected Mention Index: [22, 23] خواستید
#
# [(0, 0)]
# [(0, 0)]
# s09e09c05t|24
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیدونم
#
# [(4, 0)]
# [(4, 0)]
# s09e09c05t|43
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیخوام
#
# [(0, 0)]
# [(0, 0)]
# s09e09c06t|31
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیدونم
#
# [(0, 0)]
# [(0, 0)]
# s09e09c06t|72
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیدونم
#
# [(0, 0)]
# [(0, 0)]
# s09e09c06t|78
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونم
#
# [(1, 5)]
# [(1, 10)]
# s09e09c07t|0
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میخوایم
#
# [(10, 9)]
# [(10, 18)]
# s09e09c07t|7
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] کنم
#
# [(2, 4)]
# [(2, 8)]
# s09e09c07t|13
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] میکنی
#
# [(3, 2)]
# [(3, 4)]
# s09e09c07t|42
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] نمیتونی
#
# [(15, 11)]
# [(15, 22)]
# s09e09c07t|51
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] میدونم
#
# [(18, 12)]
# [(18, 24)]
# s09e09c07t|53
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] تو
#
# [(25, 20)]
# [(25, 40)]
# s09e09c07t|58
# Original Mention Index: ()
# Corrected Mention Index: [20, 21] خریدم
#
# [(33, 24)]
# [(33, 48)]
# s09e09c07t|63
# Original Mention Index: ()
# Corrected Mention Index: [24, 25] میدونم
#
# [(11, 10)]
# [(11, 20)]
# s09e09c07t|74
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] خریدی
#
# [(5, 4)]
# [(5, 8)]
# s09e09c07t|80
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] میکنی
#
# [(7, 12)]
# [(7, 24)]
# s09e09c07t|100
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] م
#
# [(0, 0)]
# [(0, 0)]
# s09e09c07t|107
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیدونستم
#
# [(4, 7)]
# [(4, 14)]
# s09e09c07t|109
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] داری
#
# [(0, 1)]
# [(0, 2)]
# s09e09c07t|113
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میدونم
#
# [(8, 2)]
# [(8, 4)]
# s09e09c07t|118
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] تو
#
# [(2, 1)]
# [(2, 2)]
# s09e09c07t|120
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] نمیشه
#
# [(0, 0)]
# [(0, 0)]
# s09e09c08t|0
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونی
#
# [(0, 3)]
# [(0, 6)]
# s09e09c08t|6
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] میکردی
#
# [(3, 4)]
# [(3, 8)]
# s09e09c08t|13
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] کنم
#
# [(9, 9)]
# [(9, 18)]
# s09e09c08t|17
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] عادت
#
# [(0, 0)]
# [(0, 0)]
# s09e09c08t|30
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونی
#
# [(10, 12)]
# [(10, 24)]
# s09e09c08t|48
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] میگی
#
# [(2, 3)]
# [(2, 6)]
# s09e09c08t|65
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] میکنم
#
# [(3, 3)]
# [(3, 6)]
# s09e09c08t|77
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] داشتم
#
# [(16, 10)]
# [(16, 20)]
# s09e09c09t|24
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] داشتم
#
# [(3, 3)]
# [(3, 6)]
# s09e09c09t|28
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] فهمیدی
#
# [(6, 5)]
# [(6, 10)]
# s09e09c09t|31
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] بود
#
# [(0, 2)]
# [(0, 4)]
# s09e09c09t|35
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میشناسی
#
# [(21, 16)]
# [(21, 32)]
# s09e09c09t|54
# Original Mention Index: ()
# Corrected Mention Index: [16, 17] میخوام
#
# [(23, 21)]
# [(23, 42)]
# s09e09c09t|56
# Original Mention Index: ()
# Corrected Mention Index: [21, 22] بخونی
#
# [(28, 20)]
# [(28, 40)]
# s09e09c09t|62
# Original Mention Index: ()
# Corrected Mention Index: [20, 21] نوشتم
#
# [(10, 6)]
# [(10, 12)]
# s09e09c09t|72
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] این
#
# [(15, 13)]
# [(15, 26)]
# s09e09c09t|75
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] دیدیم
#
# [(2, 0)]
# [(2, 0)]
# s09e09c09t|86
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیخوام
#
# [(10, 6)]
# [(10, 12)]
# s09e09c09t|92
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] میکنی
#
# [(17, 10)]
# [(17, 20)]
# s09e09c09t|96
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] میخوام
#
# [(25, 15)]
# [(25, 30)]
# s09e09c09t|99
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] نوشتی
#
# [(1, 1)]
# [(1, 2)]
# s09e09c09t|107
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] اینو
#
# [(17, 13)]
# [(17, 26)]
# s09e09c09t|116
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] نمیتونم
#
# [(9, 3)]
# [(9, 6)]
# s09e09c09t|121
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] نخوندیش
#
# [(0, 1)]
# [(0, 2)]
# s09e09c10t|0
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میکنم
#
# [(7, 4)]
# [(7, 8)]
# s09e09c10t|5
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] دوستیم
#
# [(11, 7)]
# [(11, 14)]
# s09e09c10t|10
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] بتونیم
#
# [(15, 11)]
# [(15, 22)]
# s09e09c10t|26
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] رفتید
#
# [(22, 14)]
# [(22, 28)]
# s09e09c10t|30
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] ملاقاتشون
#
# [(25, 18)]
# [(25, 36)]
# s09e09c10t|31
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] خوابیدی
#
# [(24, 22)]
# [(24, 44)]
# s09e09c10t|50
# Original Mention Index: ()
# Corrected Mention Index: [22, 23] شدم
#
# [(2, 0)]
# [(2, 0)]
# s09e09c10t|71
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] قاطیشون
#
# [(2, 0)]
# [(2, 0)]
# s09e09c10t|75
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] قاطیشون
#
# [(0, 0)]
# [(0, 0)]
# s09e09c10t|90
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] خوبم
#
# [(4, 1)]
# [(4, 2)]
# s09e09c10t|95
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میخوام
#
# [(2, 1)]
# [(2, 2)]
# s09e09c10t|101
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] باورت
#
# [(7, 10)]
# [(7, 20)]
# s09e09c10t|105
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] باورت
#
# [(1, 0)]
# [(1, 0)]
# s09e09c11t|0
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] بفرمایید
#
# [(13, 21)]
# [(13, 42)]
# s09e09c11t|54
# Original Mention Index: ()
# Corrected Mention Index: [21, 22] فهمیدم
#
# [(46, 37)]
# [(46, 74)]
# s09e09c11t|68
# Original Mention Index: ()
# Corrected Mention Index: [37, 38] هستم
#
# [(1, 2)]
# [(1, 4)]
# s09e09c11t|72
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میکردم
#
# [(14, 5)]
# [(14, 10)]
# s09e09c11t|85
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میخوام
#
# [(9, 11)]
# [(9, 22)]
# s09e09c11t|94
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] هستی
#
# [(2, 3)]
# [(2, 6)]
# s09e09c11t|105
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] برگردی
#
# [(7, 6)]
# [(7, 12)]
# s09e09c11t|111
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] میخوام
#
# [(16, 13)]
# [(16, 26)]
# s09e09c11t|114
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] بتونم
#
# [(29, 22)]
# [(29, 44)]
# s09e09c11t|123
# Original Mention Index: ()
# Corrected Mention Index: [22, 23] اون
#
# [(2, 5)]
# [(2, 10)]
# s09e09c11t|127
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] نرسیدیم
#
# [(19, 16)]
# [(19, 32)]
# s09e09c11t|132
# Original Mention Index: ()
# Corrected Mention Index: [16, 17] بدم
#
# [(16, 11)]
# [(16, 22)]
# s09e09c11t|151
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] هم
#
# [(0, 0)]
# [(0, 0)]
# s09e09c12t|0
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونی
#
# [(0, 5)]
# [(0, 10)]
# s09e09c12t|10
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] داشتند
#
# [(7, 9)]
# [(7, 18)]
# s09e09c12t|15
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] نبود
#
# [(0, 0)]
# [(0, 0)]
# s09e09c12t|30
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] اسمش
#
# [(24, 24)]
# [(24, 48)]
# s09e09c12t|39
# Original Mention Index: ()
# Corrected Mention Index: [24, 25] میخوره
#
# [(5, 7)]
# [(5, 14)]
# s09e09c12t|50
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] بهت
#
# [(15, 15)]
# [(15, 30)]
# s09e09c12t|54
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] ببوسی
#
# [(13, 13)]
# [(13, 26)]
# s09e09c12t|61
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] میتونی
#
# [(17, 14)]
# [(17, 28)]
# s09e09c12t|62
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] بخوریشون
#
# [(12, 7)]
# [(12, 14)]
# s09e09c12t|78
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] میدونم
#
# [(2, 3)]
# [(2, 6)]
# s09e09c12t|97
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] توه
#
# [(13, 13)]
# [(13, 26)]
# s09e09c12t|109
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] نمیتوم
#
# [(20, 15)]
# [(20, 30)]
# s09e09c12t|112
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] میتونم
#
# [(1, 1)]
# [(1, 2)]
# s09e09c12t|114
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میتونی
#
# [(3, 6)]
# [(3, 12)]
# s09e09c12t|118
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] ندیم
#
# [(12, 13)]
# [(12, 26)]
# s09e09c12t|122
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] میجنگم
#
# [(18, 16)]
# [(18, 32)]
# s09e09c12t|126
# Original Mention Index: ()
# Corrected Mention Index: [16, 17] رفتارش
#
# [(40, 32)]
# [(40, 64)]
# s09e09c12t|138
# Original Mention Index: ()
# Corrected Mention Index: [32, 33] تربیتش
#
# [(58, 47)]
# [(58, 94)]
# s09e09c12t|149
# Original Mention Index: ()
# Corrected Mention Index: [47, 48] میخورم
#
# [(0, 0)]
# [(0, 0)]
# s09e09c12t|161
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میدونم
#
# [(0, 0)]
# [(0, 0)]
# s09e09c12t|170
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] دلم
#
# [(0, 1)]
# [(0, 2)]
# s09e09c12t|178
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] کنم
#
# [(3, 5)]
# [(3, 10)]
# s09e09c12t|180
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میشم
#
# [(4, 3)]
# [(4, 6)]
# s09e09c13t|0
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] رفتی
#
# [(7, 5)]
# [(7, 10)]
# s09e09c13t|2
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] نمیتونم
#
# [(0, 3)]
# [(0, 6)]
# s09e09c13t|10
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] متاسفم
#
# [(7, 4)]
# [(7, 8)]
# s09e09c13t|13
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] میخوام
#
# [(17, 9)]
# [(17, 18)]
# s09e09c13t|18
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] میخوام
#
# [(9, 5)]
# [(9, 10)]
# s09e09c13t|31
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] نمیخوام
#
# [(18, 9)]
# [(18, 18)]
# s09e09c13t|36
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] خودمم
#
# [(52, 37)]
# [(52, 74)]
# s09e10c00t|27
# Original Mention Index: ()
# Corrected Mention Index: [37, 38] میدونم
#
# [(0, 2)]
# [(0, 4)]
# s09e10c01t|6
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میزدی
#
# [(12, 12)]
# [(12, 24)]
# s09e10c01t|13
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] میکنه
#
# [(4, 2)]
# [(4, 4)]
# s09e10c01t|25
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میزدم
#
# [(3, 4)]
# [(3, 8)]
# s09e10c01t|40
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] برگردیم
#
# [(0, 2)]
# [(0, 4)]
# s09e10c01t|44
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میکنم
#
# [(3, 3)]
# [(3, 6)]
# s09e10c01t|46
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] میدونم
#
# [(11, 9)]
# [(11, 18)]
# s09e10c01t|51
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] نمیتونم
#
# [(4, 7)]
# [(4, 14)]
# s09e10c01t|78
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] شدی
#
# [(3, 1)]
# [(3, 2)]
# s09e10c02t|30
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] تو
#
# [(12, 11)]
# [(12, 22)]
# s09e10c02t|36
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] میفته
#
# [(7, 7)]
# [(7, 14)]
# s09e10c02t|42
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] من
#
# [(25, 23)]
# [(25, 46)]
# s09e10c02t|50
# Original Mention Index: ()
# Corrected Mention Index: [23, 24] نمیتونم
#
# [(0, 2)]
# [(0, 4)]
# s09e10c02t|55
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] گفتم
#
# [(8, 8)]
# [(8, 16)]
# s09e10c02t|62
# Original Mention Index: ()
# Corrected Mention Index: [8, 9] میفهمه
#
# [(0, 5)]
# [(0, 10)]
# s09e10c02t|67
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میترسیدم
#
# [(18, 17)]
# [(18, 34)]
# s09e10c03t|35
# Original Mention Index: ()
# Corrected Mention Index: [17, 18] تو
#
# [(2, 2)]
# [(2, 4)]
# s09e10c03t|54
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] خواستم
#
# [(1, 1)]
# [(1, 2)]
# s09e10c03t|59
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] کنم
#
# [(5, 2)]
# [(5, 4)]
# s09e10c03t|74
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] ببینم
#
# [(3, 2)]
# [(3, 4)]
# s09e10c04t|0
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میدونستی
#
# [(2, 2)]
# [(2, 4)]
# s09e10c04t|24
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] چه
#
# [(6, 1)]
# [(6, 2)]
# s09e10c04t|35
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] تونستی
#
# [(0, 2)]
# [(0, 4)]
# s09e10c04t|40
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] نیست
#
# [(7, 7)]
# [(7, 14)]
# s09e10c04t|42
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] داشت
#
# [(7, 14)]
# [(7, 28)]
# s09e10c04t|47
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] ساختیم
#
# [(36, 36)]
# [(36, 72)]
# s09e10c04t|60
# Original Mention Index: ()
# Corrected Mention Index: [36, 37] میدونی
#
# [(6, 9)]
# [(6, 18)]
# s09e10c04t|70
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] داریم
#
# [(11, 6)]
# [(11, 12)]
# s09e10c04t|85
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] دیدم
#
# [(21, 15)]
# [(21, 30)]
# s09e10c04t|91
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] ترکوندید
#
# [(21, 15)]
# [(21, 30)]
# s09e10c04t|94
# Original Mention Index: ()
# Corrected Mention Index: [15, 16] ترکوندید
#
# [(28, 18)]
# [(28, 36)]
# s09e10c04t|97
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] یه
#
# [(11, 12)]
# [(11, 24)]
# s09e10c05t|3
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] کشیده
#
# [(4, 0)]
# [(4, 0)]
# s09e10c05t|28
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] داشتم
#
# [(36, 32)]
# [(36, 64)]
# s09e10c05t|49
# Original Mention Index: ()
# Corrected Mention Index: [32, 33] میخوام
#
# [(43, 38)]
# [(43, 76)]
# s09e10c05t|55
# Original Mention Index: ()
# Corrected Mention Index: [38, 39] داری
#
# [(0, 6)]
# [(0, 12)]
# s09e10c05t|65
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] میدم
#
# [(2, 1)]
# [(2, 2)]
# s09e10c06t|0
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میخوای
#
# [(0, 3)]
# [(0, 6)]
# s09e10c06t|3
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] خوبیه
#
# [(21, 12)]
# [(21, 24)]
# s09e10c06t|27
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] گفت
#
# [(23, 18)]
# [(23, 36)]
# s09e10c06t|29
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] نمیکنه
#
# [(5, 3)]
# [(5, 6)]
# s09e10c06t|32
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] ببرتت
#
# [(2, 2)]
# [(2, 4)]
# s09e10c06t|46
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] میکنی
#
# [(5, 1)]
# [(5, 2)]
# s09e10c06t|48
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] دعوتش
#
# [(13, 9)]
# [(13, 18)]
# s09e10c06t|67
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] اون
#
# [(26, 27)]
# [(26, 54)]
# s09e10c06t|76
# Original Mention Index: ()
# Corrected Mention Index: [27, 28] دارم
#
# [(10, 8)]
# [(10, 16)]
# s09e10c06t|81
# Original Mention Index: ()
# Corrected Mention Index: [8, 9] میخوای
#
# [(1, 7)]
# [(1, 14)]
# s09e10c07t|0
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] بفرستیم
#
# [(2, 1)]
# [(2, 2)]
# s09e10c07t|11
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] بنویسیم
#
# [(1, 5)]
# [(1, 10)]
# s09e10c07t|27
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میشی
#
# [(12, 8)]
# [(12, 16)]
# s09e10c07t|55
# Original Mention Index: ()
# Corrected Mention Index: [8, 9] پرت
#
# [(4, 1)]
# [(4, 2)]
# s09e10c07t|70
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] هستش
#
# [(0, 2)]
# [(0, 4)]
# s09e10c07t|81
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] 24سالشه
#
# [(4, 7)]
# [(4, 14)]
# s09e10c07t|85
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] هستش
#
# [(9, 11)]
# [(9, 22)]
# s09e10c07t|89
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] میکنه
#
# [(15, 14)]
# [(15, 28)]
# s09e10c07t|94
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] داره
#
# [(23, 21)]
# [(23, 42)]
# s09e10c07t|97
# Original Mention Index: ()
# Corrected Mention Index: [21, 22] داره
#
# [(2, 0)]
# [(2, 0)]
# s09e10c07t|100
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیدونم
#
# [(5, 4)]
# [(5, 8)]
# s09e10c08t|3
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] نمیکنه
#
# [(6, 12)]
# [(6, 24)]
# s09e10c08t|10
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] ـه
#
# [(12, 18)]
# [(12, 36)]
# s09e10c08t|14
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] کنی
#
# [(7, 5)]
# [(7, 10)]
# s09e10c08t|21
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] مراقبشم
#
# [(2, 1)]
# [(2, 2)]
# s09e10c08t|33
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] میخوای
#
# [(8, 9)]
# [(8, 18)]
# s09e10c08t|36
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] بود
#
# [(14, 7)]
# [(14, 14)]
# s09e10c08t|56
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] منه
#
# [(4, 3)]
# [(4, 6)]
# s09e10c08t|62
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] برداشت
#
# [(10, 12)]
# [(10, 24)]
# s09e10c09t|4
# Original Mention Index: ()
# Corrected Mention Index: [12, 13] میکنه
#
# [(126, 127)]
# [(126, 254)]
# s09e10c09t|62
# Original Mention Index: ()
# Corrected Mention Index: [127, 128] میتونم
#
# [(3, 1)]
# [(3, 2)]
# s09e10c09t|68
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] برگردیم
#
# [(6, 6)]
# [(6, 12)]
# s09e10c09t|83
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] دیگه
#
# [(1, 6)]
# [(1, 12)]
# s09e10c09t|84
# Original Mention Index: ()
# Corrected Mention Index: [6, 7] میشه
#
# [(6, 10)]
# [(6, 20)]
# s09e10c09t|86
# Original Mention Index: ()
# Corrected Mention Index: [10, 11] میتونی
#
# [(22, 22)]
# [(22, 44)]
# s09e10c09t|98
# Original Mention Index: ()
# Corrected Mention Index: [22, 23] نمیتونم
#
# [(4, 2)]
# [(4, 4)]
# s09e10c09t|102
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] داره
#
# [(7, 3)]
# [(7, 6)]
# s09e10c09t|104
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] میخورتش
#
# [(2, 1)]
# [(2, 2)]
# s09e10c10t|11
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] ماست
#
# [(3, 1)]
# [(3, 2)]
# s09e10c10t|20
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] کردی
#
# [(7, 7)]
# [(7, 14)]
# s09e10c10t|34
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] انداختنمون
#
# [(2, 0)]
# [(2, 0)]
# s09e10c10t|45
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میخوای
#
# [(0, 2)]
# [(0, 4)]
# s09e10c10t|55
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] نیست
#
# [(21, 27)]
# [(21, 54)]
# s09e10c10t|77
# Original Mention Index: ()
# Corrected Mention Index: [27, 28] کردم
#
# [(0, 3)]
# [(0, 6)]
# s09e10c11t|0
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] ست
#
# [(8, 11)]
# [(8, 22)]
# s09e10c11t|12
# Original Mention Index: ()
# Corrected Mention Index: [11, 12] کرد
#
# [(18, 13)]
# [(18, 26)]
# s09e10c11t|17
# Original Mention Index: ()
# Corrected Mention Index: [13, 14] شد
#
# [(4, 5)]
# [(4, 10)]
# s09e10c11t|33
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] فکرم
#
# [(28, 19)]
# [(28, 38)]
# s09e10c11t|39
# Original Mention Index: ()
# Corrected Mention Index: [19, 20] میدونی
#
# [(7, 5)]
# [(7, 10)]
# s09e10c11t|46
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میدونم
#
# [(3, 7)]
# [(3, 14)]
# s09e10c11t|60
# Original Mention Index: ()
# Corrected Mention Index: [7, 8] کشیدم
#
# [(0, 0)]
# [(0, 0)]
# s09e10c12t|8
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] داره
#
# [(5, 5)]
# [(5, 10)]
# s09e10c12t|20
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] هست
#
# [(2, 3)]
# [(2, 6)]
# s09e10c12t|27
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] میگه
#
# [(2, 5)]
# [(2, 10)]
# s09e10c12t|45
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] هستش
#
# [(21, 20)]
# [(21, 40)]
# s09e10c12t|53
# Original Mention Index: ()
# Corrected Mention Index: [20, 21] تسلا
#
# [(30, 31)]
# [(30, 62)]
# s09e10c12t|58
# Original Mention Index: ()
# Corrected Mention Index: [31, 32] میکرد
#
# [(43, 60)]
# [(43, 120)]
# s09e10c12t|82
# Original Mention Index: ()
# Corrected Mention Index: [60, 61] هستش
#
# [(60, 65)]
# [(60, 130)]
# s09e10c12t|89
# Original Mention Index: ()
# Corrected Mention Index: [65, 66] نیستم
#
# [(65, 67)]
# [(65, 134)]
# s09e10c12t|91
# Original Mention Index: ()
# Corrected Mention Index: [67, 68] نیستم
#
# [(6, 4)]
# [(6, 8)]
# s09e10c13t|1
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] ایناهاشش
#
# [(12, 5)]
# [(12, 10)]
# s09e10c13t|3
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] بریم
#
# [(1, 0)]
# [(1, 0)]
# s09e10c13t|24
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] میتونی
#
# [(13, 18)]
# [(13, 36)]
# s09e10c13t|29
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] میده
#
# [(1, 0)]
# [(1, 0)]
# s09e10c13t|43
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] بعدش
#
# [(26, 18)]
# [(26, 36)]
# s09e10c13t|54
# Original Mention Index: ()
# Corrected Mention Index: [18, 19] میکنه
#
# [(0, 0)]
# [(0, 0)]
# s09e10c13t|56
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیتونم
#
# [(4, 1)]
# [(4, 2)]
# s09e10c13t|61
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] نداره
#
# [(10, 3)]
# [(10, 6)]
# s09e10c13t|62
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] نداره
#
# [(14, 5)]
# [(14, 10)]
# s09e10c13t|64
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] شد
#
# [(2, 4)]
# [(2, 8)]
# s09e10c13t|66
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] میکنه
#
# [(4, 3)]
# [(4, 6)]
# s09e10c13t|69
# Original Mention Index: ()
# Corrected Mention Index: [3, 4] نیست
#
# [(10, 4)]
# [(10, 8)]
# s09e10c13t|71
# Original Mention Index: ()
# Corrected Mention Index: [4, 5] بخورتش
#
# [(1, 1)]
# [(1, 2)]
# s09e10c13t|79
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] بریم
#
# [(0, 1)]
# [(0, 2)]
# s09e10c14t|0
# Original Mention Index: ()
# Corrected Mention Index: [1, 2] عجبم
#
# [(0, 0)]
# [(0, 0)]
# s09e10c14t|10
# Original Mention Index: ()
# Corrected Mention Index: [0, 1] نمیدونم
#
# [(13, 9)]
# [(13, 18)]
# s09e10c14t|26
# Original Mention Index: ()
# Corrected Mention Index: [9, 10] برگردیم
#
# [(13, 14)]
# [(13, 28)]
# s09e10c14t|36
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] فهمیدم
#
# [(0, 2)]
# [(0, 4)]
# s09e10c14t|44
# Original Mention Index: ()
# Corrected Mention Index: [2, 3] هستش
#
# [(4, 5)]
# [(4, 10)]
# s09e10c14t|47
# Original Mention Index: ()
# Corrected Mention Index: [5, 6] میدونم
#
# [(14, 14)]
# [(14, 28)]
# s09e10c14t|53
# Original Mention Index: ()
# Corrected Mention Index: [14, 15] نیست
#
# [(25, 26)]
# [(25, 52)]
# s09e10c14t|71
# Original Mention Index: ()
# Corrected Mention Index: [26, 27] نمتونستم
#
# [(32, 31)]
# [(32, 62)]
# s09e10c14t|73
# Original Mention Index: ()
# Corrected Mention Index: [31, 32] میتونم
#
# [(40, 38)]
# [(40, 76)]
# s09e10c14t|77
# Original Mention Index: ()
# Corrected Mention Index: [38, 39] دارم
#
# [(44, 48)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/w9/673mfrb56v7dvx7hhvw7s6240000gn/T/ipykernel_74607/3587674548.py in <module>
#      79         if len(corrected_result_with_drop)==1 and corrected_result_with_drop[0][1]%2==0:
#      80             drop_add_num += 1
# ---> 81             print(corrected_result)
#      82             print(corrected_result_with_drop)
#      83             print(mention_id)
#
# ~/.conda/envs/multi_coref/lib/python3.8/site-packages/ipykernel/iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/.conda/envs/multi_coref/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~/.conda/envs/multi_coref/lib/python3.8/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     545                 )
#     546             data.group = group
# --> 547         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     548
#     549     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.conda/envs/multi_coref/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
sample = coe_annotations[0]
for item in sample:
    print(item)
    print(sample[item])
    print()
# Out:
# HITId
# 710846
#
# HITTypeId
# 931
#
# Title
# TASA
#
# CreationTime
# Thu Jul 14 17:59:04 UTC 2022
#
# MaxAssignments
# 1
#
# AssignmentDurationInSeconds
# 86400
#
# AssignmentId
# 25222
#
# WorkerId
# 51
#
# AcceptTime
# Thu Jul 14 18:01:27 UTC 2022
#
# SubmitTime
# Thu Jul 14 18:01:50 UTC 2022
#
# WorkTimeInSeconds
# 23
#
# Input.config_obj
# {"src_enable_retokenize": false, "version": {"PATCH": 0, "MAJOR": 1, "MINOR": 0}, "tar_enable_retokenize": false,"src_head_inds":[0],"alignment":[[true, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false], [false, false, false, false]]}
#
# Input.src_tokens
# ['There', 'you', 'go', '.', 'You', "'re", 'all', 'done', '!']
#
# Input.tar_tokens
# ["\u0631\u062f\u06cc\u0641", "", "\u0634\u062f", ""]
#
# Answer.alignment
# [[false,false,false,false],[false,false,false,false],[false,false,false,false],[false,false,false,false],[false,false,false,false],[false,false,false,false],[false,false,false,false],[false,false,false,false],[false,false,false,false]]
#
# Answer.src_tokens
# undefined
#
# Answer.tar_tokens
# undefined
#
# Turkle.Username
# mahsay

# %%
"""
TACL Revision
"""

num_corrected = 0
num_add = 0
num_delete = 0
num_modify = 0
drop_add_num = 0
drop_delete_num = 0
drop_modify_num = 0

correction_dict = {}
remove_set = set()
add_dict = {}

all_correction_lines = []
for i in range(len(coe_annotations)):
    original_result = extract_alignment_pair_space(json.loads(coe_annotations[i]['Input.config_obj'])['alignment'])
    corrected_result = extract_alignment_pair_space(json.loads(coe_annotations[i]['Answer.alignment']))
    original_result_with_drop = extract_alignment_pair_original(json.loads(coe_annotations[i]['Input.config_obj'])['alignment'])
    corrected_result_with_drop = extract_alignment_pair_original(json.loads(coe_annotations[i]['Answer.alignment']))

    # print(original_result)
    # print(original_result_with_drop)
    # print(corrected_result)
    # print(corrected_result_with_drop)
    # print()

    if original_result==corrected_result:
        continue
    mention_id = source_data[i]['mention_id']

    a = ()
    b = ()
    c = ()
    if original_result!=[]:
        a = extract_pair(original_result)
    if corrected_result!=[]:
        b = extract_pair(corrected_result)
    if mention_id in mention_dict_fa:
        c = [mention_dict_fa[mention_id][1], mention_dict_fa[mention_id][2]]

    # sentence = ast.literal_eval(coe_annotations[i]['Input.tar_tokens'])
    sentence = ast.literal_eval(source_data[i]['tar_tokens'])
    original_text = ""
    corrected_text = ""
    if a!=():
        original_text = " ".join(sentence[a[0]: a[1]])
    if b!=():
        corrected_text = " ".join(sentence[b[0]: b[1]])

    # Retrieve the input and target tokens
    input_tokens = ast.literal_eval(coe_annotations[i]['Input.src_tokens'])
    target_tokens = ast.literal_eval(coe_annotations[i]['Input.tar_tokens'])
    target_tokens.reverse()
    corrected_target_mention_str = " ".join([target_tokens[item[1]] for item in corrected_result_with_drop])
    # print(corrected_target_mention_str)
    # print(input_tokens)
    # print(target_tokens)
    # print(original_result_with_drop, [(input_tokens[item[0]], target_tokens[item[1]]) for item in original_result_with_drop])
    # print(corrected_result_with_drop, [(input_tokens[item[0]], target_tokens[item[1]]) for item in corrected_result_with_drop])
    # print(target_mention_str)
    # print("=="*50)

    if a==() and b!=():
        num_add += 1
        input_tokens = ast.literal_eval(coe_annotations[i]['Input.src_tokens'])
        target_tokens = ast.literal_eval(coe_annotations[i]['Input.tar_tokens'])
        # if target_mention_str=="":
        #     print(input_tokens)
        #     print(target_tokens)
        #     print(original_result_with_drop, [(input_tokens[item[0]], target_tokens[item[1]]) for item in original_result_with_drop])
        #     print(corrected_result_with_drop, [(input_tokens[item[0]], target_tokens[item[1]]) for item in corrected_result_with_drop])
        #     print(target_mention_str)
        #     print("=="*50)

        if corrected_target_mention_str=="":
            drop_add_num += 1
            # print(corrected_result)
            # print(corrected_result_with_drop)
            # print(mention_id)
            # print("Original Mention Index:", a, original_text)
            # print("Corrected Mention Index:", b, corrected_text)
            # print()
    if a!=() and b==():
        num_delete += 1
        # print(input_tokens)
        # print(target_tokens)
        # print(original_result_with_drop, [(input_tokens[item[0]], target_tokens[item[1]]) for item in original_result_with_drop])
        # print(corrected_result_with_drop, [(input_tokens[item[0]], target_tokens[item[1]]) for item in corrected_result_with_drop])
        # print(target_mention_str)
        # print("=="*50)
        if corrected_target_mention_str=="":
            drop_delete_num += 1
    if a!=() and b!=():
        num_modify += 1
        if corrected_target_mention_str=="":
            drop_modify_num += 1
            # print(corrected_result)
            # print(corrected_result_with_drop)
            # print()

    all_correction_lines.append([
        mention_id,
        a,
        b,
        original_text,
        corrected_text
    ])
    # print(source_data[i]['mention_id'], a, b)
    # print(mention_dict[mention_id], a)
    # print()

    # if source_data[i]['mention_id'] in mention_dict:
    #     mention_id = source_data[i]['mention_id']
    #     target = mention_dict[source_data[i]['mention_id']][1:]
    #     correction_dict[mention_id] = [a, b]
    if b==(): # Add mention_id to remove set
        remove_set.add(source_data[i]['mention_id'])
    elif a==(): # Collect mentions to add
        add_dict[source_data[i]['mention_id']] = [mention_dict[mention_id][0], b[0], b[1]]
    else:
        correction_dict[source_data[i]['mention_id']] = [mention_dict[mention_id][0], b[0], b[1]]

# %%
print(drop_add_num, drop_add_num/len(coe_annotations)*100)
print(drop_delete_num, drop_add_num/len(coe_annotations)*100)
print(drop_modify_num, drop_add_num/len(coe_annotations)*100)

print(num_add, num_add/len(coe_annotations)*100)
print(num_delete, num_delete/len(coe_annotations)*100)
print(num_modify, num_modify/len(coe_annotations)*100)
print(num_corrected, num_corrected/len(coe_annotations)*100)
# Out:
# 739 9.592419522326065
# 187 9.592419522326065
# 84 9.592419522326065
# 1504 19.52232606438214
# 187 2.427310488058152
# 794 10.306334371754932
# 0 0.0

# %%
print(count, len(source_inputs), count/len(source_inputs)*100)
# Out:
# 2485 7704 32.25597092419522

# %%
# print((187)/2485*100)
# print((1504)/2485*100)
# print((2485-1504-187)/2485*100)
print((187)/len(source_inputs)*100)
print((1504)/len(source_inputs)*100)
print((2485-1504-187)/len(source_inputs)*100)
# Out:
# 2.427310488058152
# 19.52232606438214
# 10.306334371754932

# %%
print(count/len(coe_annotations), count, len(coe_annotations))
# Out:
# 0.3225597092419522 2485 7704

# %%
print(['اونقدرا', '', 'هم', '', 'بد', '', 'نبود', '', 'خشگله', '', 'اگه', '', 'مامانم', '', 'میتونست', '', 'الان', '', 'ببینتم', '', 'توی', '', 'کمد', '', 'گناهکارا', '', 'زندانیم', '', 'میکرد', ''][3: 4])
# Out:
# ['']

# %%
import pickle as pkl

scene_ids = set()
for item in correction_dict:
    scene_ids.add(item[:10])
for item in remove_set:
    scene_ids.add(item[:10])
for item in add_dict:
    scene_ids.add(item[:10])

all_results = {}
for item in scene_ids:
    all_results[item] = {
        "correction_dict": {},
        "remove_set": set(),
        "add_dict": {}
    }

for item in remove_set:
    all_results[item[:10]]['remove_set'].add(item)
for item in correction_dict:
    all_results[item[:10]]['correction_dict'][item] = correction_dict[item]
for item in add_dict:
    all_results[item[:10]]['add_dict'][item] = add_dict[item]

with open('data/fa/correction_results.pkl', 'wb') as f:
    pkl.dump(all_results, f)

# %%
names = ['correction_dict', 'remove_set', 'add_dict']
for scene_id in all_results:
    print(scene_id)
    for name in names:
        print(name, all_results[scene_id][name])
    print()
# Out:
# s09e10c05t
# correction_dict {'s09e10c05t|0': [0, 6, 8], 's09e10c05t|2': [0, 3, 4], 's09e10c05t|4': [0, 15, 22], 's09e10c05t|19': [3, 6, 7], 's09e10c05t|26': [4, 0, 7], 's09e10c05t|53': [6, 33, 36], 's09e10c05t|54': [6, 33, 39], 's09e10c05t|58': [6, 49, 56], 's09e10c05t|59': [6, 51, 55]}
# remove_set {'s09e10c05t|8', 's09e10c05t|7'}
# add_dict {'s09e10c05t|3': [0, 12, 13], 's09e10c05t|28': [4, 0, 1], 's09e10c05t|40': [6, 12, 13], 's09e10c05t|44': [6, 19, 20], 's09e10c05t|49': [6, 32, 33], 's09e10c05t|55': [6, 38, 39], 's09e10c05t|65': [7, 6, 7], 's09e10c05t|78': [8, 4, 5]}
#
# s09e16c04t
# correction_dict {}
# remove_set set()
# add_dict {'s09e16c04t|0': [0, 2, 3], 's09e16c04t|6': [0, 7, 8], 's09e16c04t|9': [1, 5, 6], 's09e16c04t|13': [3, 0, 1], 's09e16c04t|19': [6, 1, 2], 's09e16c04t|25': [7, 2, 3], 's09e16c04t|32': [8, 9, 10], 's09e16c04t|41': [9, 3, 4], 's09e16c04t|51': [10, 11, 12]}
#
# s09e11c08t
# correction_dict {'s09e11c08t|22': [4, 7, 11], 's09e11c08t|25': [5, 3, 7], 's09e11c08t|60': [10, 4, 12], 's09e11c08t|78': [13, 2, 3], 's09e11c08t|123': [17, 7, 8]}
# remove_set set()
# correction_dict {'s09e11c04t|9': [1, 4, 6], 's09e11c04t|17': [2, 9, 11], 's09e11c04t|30': [5, 4, 8], 's09e11c04t|33': [5, 10, 11], 's09e11c04t|36': [5, 12, 15], 's09e11c04t|50': [5, 17, 21], 's09e11c04t|63': [5, 34, 39]}
# remove_set set()
# add_dict {'s09e11c04t|12': [2, 2, 3], 's09e11c04t|19': [4, 3, 4], 's09e11c04t|26': [5, 1, 2], 's09e11c04t|45': [5, 23, 24], 's09e11c04t|49': [5, 24, 25], 's09e11c04t|52': [5, 28, 29], 's09e11c04t|56': [5, 31, 32], 's09e11c04t|58': [5, 32, 33]}
#
# s09e16c11t
# correction_dict {'s09e16c11t|12': [2, 2, 4], 's09e16c11t|31': [4, 33, 35]}
# remove_set set()
# add_dict {'s09e16c11t|11': [2, 4, 5], 's09e16c11t|15': [2, 7, 8], 's09e16c11t|27': [4, 30, 31]}
#
# s09e04c11t
# correction_dict {'s09e04c11t|26': [2, 22, 23], 's09e04c11t|35': [3, 12, 13], 's09e04c11t|74': [8, 6, 11], 's09e04c11t|77': [8, 15, 20], 's09e04c11t|91': [9, 14, 17], 's09e04c11t|100': [10, 1, 5], 's09e04c11t|111': [11, 6, 8], 's09e04c11t|118': [14, 0, 2], 's09e04c11t|119': [14, 1, 6]}
# remove_set {'s09e04c11t|104', 's09e04c11t|29', 's09e04c11t|62'}
# add_dict {'s09e04c11t|0': [0, 1, 2], 's09e04c11t|13': [1, 6, 7], 's09e04c11t|22': [2, 2, 3], 's09e04c11t|46': [4, 3, 4], 's09e04c11t|86': [9, 7, 8], 's09e04c11t|89': [9, 16, 17], 's09e04c11t|106': [10, 7, 8], 's09e04c11t|108': [11, 2, 3], 's09e04c11t|131': [15, 7, 8]}
#
# s09e11c07t
# correction_dict {'s09e11c07t|28': [2, 7, 13], 's09e11c07t|39': [4, 5, 6], 's09e11c07t|50': [5, 18, 19]}
# remove_set set()
# add_dict {'s09e11c07t|1': [0, 18, 19], 's09e11c07t|5': [0, 18, 19], 's09e11c07t|25': [2, 4, 5], 's09e11c07t|29': [2, 19, 20], 's09e11c07t|46': [5, 13, 14], 's09e11c07t|48': [5, 14, 15]}
#
# s09e12c15t
# correction_dict {'s09e12c15t|15': [1, 18, 19]}
# remove_set {'s09e12c15t|6', 's09e12c15t|22', 's09e12c15t|4'}
# add_dict {'s09e12c15t|2': [0, 4, 5], 's09e12c15t|13': [1, 9, 10], 's09e12c15t|20': [2, 4, 5]}
#
# s09e16c14t
# correction_dict {'s09e16c14t|5': [0, 11, 16]}
# remove_set set()
# add_dict {'s09e16c14t|2': [0, 3, 4]}
#
# s01e13c04f
# correction_dict {'s01e13c04f|43': [6, 2, 4]}
# remove_set set()
# add_dict {'s01e13c04f|31': [5, 9, 10]}
#
# s09e16c13t
# correction_dict {}
# remove_set set()
# add_dict {'s09e16c13t|2': [2, 1, 2]}
#
# s01e14c14f
# correction_dict {'s01e14c14f|100': [7, 82, 88], 's01e14c14f|113': [7, 105, 106], 's01e14c14f|116': [7, 101, 103], 's01e14c14f|144': [7, 156, 158], 's01e14c14f|155': [10, 0, 10], 's01e14c14f|157': [10, 5, 9], 's01e14c14f|186': [12, 5, 13], 's01e14c14f|190': [12, 9, 11]}
# correction_dict {'s01e14c04f|9': [2, 10, 21], 's01e14c04f|10': [2, 0, 8], 's01e14c04f|26': [3, 5, 18], 's01e14c04f|27': [3, 12, 18], 's01e14c04f|70': [7, 1, 3], 's01e14c04f|84': [8, 9, 11], 's01e14c04f|98': [10, 4, 6], 's01e14c04f|124': [14, 4, 5]}
# remove_set {'s01e14c04f|69', 's01e14c04f|18'}
# add_dict {'s01e14c04f|1': [0, 18, 19], 's01e14c04f|6': [1, 4, 5], 's01e14c04f|8': [2, 2, 7], 's01e14c04f|63': [6, 4, 5], 's01e14c04f|66': [6, 9, 10], 's01e14c04f|72': [8, 6, 8], 's01e14c04f|82': [8, 10, 11], 's01e14c04f|110': [10, 13, 14], 's01e14c04f|113': [12, 1, 2], 's01e14c04f|118': [12, 4, 6], 's01e14c04f|128': [14, 12, 13]}

# %%
# Write correction results to csv files
with open('farsi_correction_results.csv', 'w', encoding="utf-8") as csv_w:
    fieldnames = ['Mention ID', 'Original Mention Index', 'Corrected Mention Index', 'Original Mention Text', 'Corrected Mention Text']
    writer = csv.DictWriter(csv_w, fieldnames, lineterminator='\n', quoting=csv.QUOTE_ALL)
    writer.writeheader()
    for line in all_correction_lines:
        writer.writerow({
            fieldnames[0]: line[0],
            fieldnames[1]: line[1],
            fieldnames[2]: line[2],
            fieldnames[3]: line[3],
            fieldnames[4]: line[4],
        })

# %%
print(all_correction_lines[0])
# Out:
# ['s09e03c09t|0', [0, 1], (), 'ردیف', '']

# %%
print(all_results)
# Out:
# {'s09e09c07t': {'correction_dict': {'s09e09c07t|50': [8, 16, 19], 's09e09c07t|97': [13, 1, 3], 's09e09c07t|104': [13, 10, 13], 's09e09c07t|111': [14, 7, 9], 's09e09c07t|117': [15, 9, 12]}, 'remove_set': {'s09e09c07t|56', 's09e09c07t|31', 's09e09c07t|23', 's09e09c07t|5', 's09e09c07t|38', 's09e09c07t|39'}, 'add_dict': {'s09e09c07t|0': [0, 2, 3], 's09e09c07t|41': [8, 2, 4], 's09e09c07t|63': [8, 45, 46], 's09e09c07t|78': [10, 1, 2], 's09e09c07t|92': [11, 7, 8], 's09e09c07t|98': [13, 5, 6], 's09e09c07t|102': [13, 9, 10], 's09e09c07t|105': [13, 10, 11], 's09e09c07t|115': [15, 9, 10]}}, 's09e04c07t': {'correction_dict': {'s09e04c07t|13': [2, 15, 18], 's09e04c07t|17': [2, 9, 14], 's09e04c07t|38': [6, 14, 17]}, 'remove_set': {'s09e04c07t|70', 's09e04c07t|67'}, 'add_dict': {'s09e04c07t|11': [2, 9, 11], 's09e04c07t|27': [5, 7, 8], 's09e04c07t|36': [6, 14, 15], 's09e04c07t|57': [6, 30, 31], 's09e04c07t|83': [9, 13, 15]}}, 's09e10c04t': {'correction_dict': {'s09e10c04t|15': [3, 1, 2], 's09e10c04t|16': [3, 1, 5], 's09e10c04t|22': [3, 24, 25], 's09e10c04t|28': [4, 11, 34], 's09e10c04t|37': [5, 9, 12], 's09e10c04t|59': [7, 37, 38], 's09e10c04t|76': [9, 3, 4], 's09e10c04t|107': [12, 1, 2]}, 'remove_set': {'
'那', '死', '的'], [], ['呃', '.', '.', '.', '大', '概', '是', '十', '十', '二', '个', '月', '以', '前', '吧'], ['你', '竟', '然', '瞒', '了', '我', '一', '整', '年', '?'], ['呃', '有', '其', '女', '必', '有', '其', '父', '吗', '对', '吧', '?', '我', '爱', '你', '伙', '计', '我', '得', '挂', '了', '!'], ['呃', '该', '你', '了']], 'annotations': [{'query': {'sentenceIndex': 0, 'startToken': 1, 'endToken': 3, 'mention_id': 's09e03c09t|0'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}, {'query': {'sentenceIndex': 0, 'startToken': 4, 'endToken': 6, 'mention_id': 's09e03c09t|3'}, 'antecedents': ['Amy']}, {'query': {'sentenceIndex': ...

# %%
# Perform Correction
with open('data/zh/source/all_coref_data_en_zh_finalized.json', 'r') as f:
    source = json.load(f)

# %%
output = []
for i, scene in enumerate(source):
    if scene['scene_id'] != "s09e07c07t":
        continue
    new_annotations = []
    annotations = deepcopy(scene['annotations'])
    for item in annotations:
        query = deepcopy(item['query'])
        antecedents = deepcopy(item['antecedents'])
        # print(query, antecedents)
        # Correct Query
        if query['mention_id'] in correction_dict:
            print(query, correction_dict[query['mention_id']])

        new_annotations.append({
            "query": query,
            "antecedents": antecedents
        })
# Out:
# {'sentenceIndex': 1, 'startToken': 0, 'endToken': 1, 'mention_id': 's09e07c07t|2'} [[0, 1], [15, 16]]
# {'sentenceIndex': 1, 'startToken': 43, 'endToken': 45, 'mention_id': 's09e07c07t|7'} [[43, 45], ()]
# {'sentenceIndex': 2, 'startToken': 1, 'endToken': 4, 'mention_id': 's09e07c07t|8'} [[1, 4], ()]
# {'sentenceIndex': 2, 'startToken': 4, 'endToken': 6, 'mention_id': 's09e07c07t|10'} [[4, 6], ()]
# {'sentenceIndex': 4, 'startToken': 8, 'endToken': 10, 'mention_id': 's09e07c07t|13'} [[8, 10], ()]
# {'sentenceIndex': 5, 'startToken': 8, 'endToken': 9, 'mention_id': 's09e07c07t|19'} [[8, 9], [17, 18]]
# {'sentenceIndex': 7, 'startToken': 3, 'endToken': 4, 'mention_id': 's09e07c07t|30'} [[3, 4], ()]
# {'sentenceIndex': 7, 'startToken': 3, 'endToken': 4, 'mention_id': 's09e07c07t|30'} [[3, 4], ()]
# {'sentenceIndex': 7, 'startToken': 10, 'endToken': 12, 'mention_id': 's09e07c07t|33'} [[10, 12], ()]
# {'sentenceIndex': 8, 'startToken': 3, 'endToken': 5, 'mention_id': 's09e07c07t|44'} [[3, 5], ()]
# {'sentenceIndex': 8, 'startToken': 7, 'endToken': 9, 'mention_id': 's09e07c07t|46'} [[7, 9], ()]
# {'sentenceIndex': 9, 'startToken': 4, 'endToken': 6, 'mention_id': 's09e07c07t|49'} [[4, 6], ()]
# {'sentenceIndex': 10, 'startToken': 8, 'endToken': 9, 'mention_id': 's09e07c07t|52'} [[8, 9], ()]
# {'sentenceIndex': 10, 'startToken': 12, 'endToken': 13, 'mention_id': 's09e07c07t|54'} [[12, 13], ()]
# {'sentenceIndex': 11, 'startToken': 2, 'endToken': 8, 'mention_id': 's09e07c07t|55'} [[2, 8], [14, 15]]
# {'sentenceIndex': 11, 'startToken': 9, 'endToken': 25, 'mention_id': 's09e07c07t|58'} [[9, 25], [24, 25]]
# {'sentenceIndex': 11, 'startToken': 20, 'endToken': 21, 'mention_id': 's09e07c07t|62'} [[20, 21], ()]
# {'sentenceIndex': 11, 'startToken': 38, 'endToken': 47, 'mention_id': 's09e07c07t|66'} [[38, 47], [38, 47]]
# {'sentenceIndex': 11, 'startToken': 54, 'endToken': 55, 'mention_id': 's09e07c07t|72'} [[54, 55], ()]
# {'sentenceIndex': 11, 'startToken': 34, 'endToken': 36, 'mention_id': 's09e07c07t|74'} [[34, 36], ()]
# {'sentenceIndex': 13, 'startToken': 27, 'endToken': 28, 'mention_id': 's09e07c07t|86'} [[27, 28], ()]
# {'sentenceIndex': 13, 'startToken': 18, 'endToken': 20, 'mention_id': 's09e07c07t|90'} [[18, 20], ()]
# {'sentenceIndex': 14, 'startToken': 0, 'endToken': 10, 'mention_id': 's09e07c07t|95'} [[0, 10], ()]
# {'sentenceIndex': 15, 'startToken': 4, 'endToken': 5, 'mention_id': 's09e07c07t|96'} [[4, 5], ()]
# {'sentenceIndex': 15, 'startToken': 4, 'endToken': 5, 'mention_id': 's09e07c07t|97'} [[4, 5], ()]
# {'sentenceIndex': 16, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e07c07t|102'} [[0, 2], [4, 6]]

# %%
print(correction_dict['s09e07c07t|30'])
# Out:
# [[3, 4], ()]

# %%
print(all_data['s09e07c07t'])
# Out:
# {'sentences': [[], ['你', '在', '这', '里', '感', '觉', '还', '好', '嘛', '?', '没', '事', '挺', '好', '的', '我', '感', '觉', '自', '己', '像', '个', '考', '古', '学', '家', '像', '是', 'I', 'n', 'd', 'i', 'a', 'n', 'a', 'J', 'o', 'n', 'e', 's', '与', '独', '栋', '别', '墅', '嘿', '看', '啊', '!'], ['我', '捡', '了', '个', '贝', '壳'], [], ['其', '实', '是', '老', '鼠', '的', '骨', '头', '淡', '定'], ['这', '的', '灰', '尘', '够', '多', '的', '了', '你', '就', '别', '再', '折', '腾', '了', '抱', '歉', '你', '知', '道', '.', '.', '.', '这', '里', '是', '什', '么', '位', '置', '吗', '?'], ['E', 'M', 'P', 'T', 'Y'], ['大', '概', '吧', '我', '觉', '得', '那', '边', '是', '小', '客', '厅'], ['好', '吧', '那', '这', '里', '就', '是', '餐', '厅', '了', '没', '错'], ['不', '过', '把', '小', '客', '厅', '改', '造', '成', '婴', '儿', '室', '也', '不', '会', '很', '费', '事'], ['我', '为', '什', '么', '会', '不', '想', '听', '你', '说', '这', '件', '事', '?'], ['因', '为', 'B', 'e', 'r', 'n', 'i', 'e', '说', '你', '不', '想', '要', '孩', '子', '不', '是', '这', '样', '的', '我', '.', '.', '.', '我', '很', '希', '望', '她', '能', '怀', '上', '一', '个', '宝', '宝', '真', '的', '一', '有', '机', '会', '我', '就', '扑', '倒', '她', '那', '个', '.', '.', '.', '当', '然', '我', '也', '很', '温', '柔', '的', '唔', '重', '点', '是'], [], ['是', '嘛', '我', '不', '知', '道', '她', '为', '什', '么', '没', '跟', '你', '说', '实', '话', '不', '过', '明', '明', '是', '她', '不', '想', '要', '孩', '子', '的'], ['而', '且', '每', '次', '我', '提', '起', '这', '件', '事', '的', '时', '候', '.', '.', '.'], ['地', '震', '啦', '!', '天', '啊', '咱', '俩', '死', '定', '了', '!'], ['地', '震', '啦', '!', '余', '震', '啦', '.', '.', '.']], 'annotations': [{'query': {'sentenceIndex': 1, 'startToken': 0, 'endToken': 1, 'mention_id': 's09e07c07t|2'}, 'antecedents': ['Howard']}, {'query': {'sentenceIndex': 1, 'startToken': 21, 'endToken': 26, 'mention_id': 's09e07c07t|4'}, 'antecedents': [{'sentenceIndex': 1, 'startToken': 0, 'endToken': 1, 'mention_id': 's09e07c07t|5'}]}, {'query': {'sentenceIndex': 1, 'startToken': 41, 'endToken': 45, 'mention_id': 's09e07c07t|6'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}, {'query': {'sentenceIndex': 1, 'startToken': 43, 'endToken': 45, 'mention_id': 's09e07c07t|7'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}, {'query': {'sentenceIndex': 2, 'startToken': 1, 'endToken': 4, 'mention_id': 's09e07c07t|8'}, 'antecedents': [{'sentenceIndex': 1, 'startToken': 43, 'endToken': 45, 'mention_id': 's09e07c07t|9'}]}, {'query': {'sentenceIndex': 2, 'startToken': 4, 'endToken': 6, 'mention_id': 's09e07c07t|10'}, 'antecedents': [{'sentenceIndex': 2, 'startToken': 1, 'endToken': 4, 'mention_id': 's09e07c07t|11'}]}, {'query': {'sentenceIndex': 4, 'startToken': 8, 'endToken': 10, 'mention_id': 's09e07c07t|13'}, 'antecedents': ['null_projection']}, {'query': {'sentenceIndex': 5, 'startToken': 8, 'endToken': 9, 'mention_id': 's09e07c07t|19'}, 'antecedents': ['Mr Rostenkowski']}, {'query': {'sentenceIndex': 5, 'startToken': 18, 'endToken': 30, 'mention_id': 's09e07c07t|21'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}, {'query': {'sentenceIndex': 7, 'startToken': 3, 'endToken': 4, 'mention_id': 's09e07c07t|30'}, 'antecedents': ['Howard']}, {'query': {'sentenceIndex': 7, 'startToken': 3, 'endToken': 4, 'mention_id': 's09e07c07t|30'}, 'antecedents': ['Mr Rostenkowski']}, {'query': {'sentenceIndex': 7, 'startToken': 10, 'endToken': 12, 'mention_id': 's09e07c07t|33'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}, {'query': {'sentenceIndex': 8, 'startToken': 3, 'endToken': 5, 'mention_id': 's09e07c07t|40'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}, {'query': {'sentenceIndex': 8, 'startToken': 3, 'endToken': 5, 'mention_id': 's09e07c07t|44'}, 'antecedents': ['null_projection']}, {'query': {'sentenceIndex': 8, 'startToken': 7, 'endToken': 9, 'mention_id': 's09e07c07t|46'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}, {'query': {'sentenceIndex': 9, 'startToken': 4, 'endToken': 6, 'mention_id': 's09e07c07t|49'}, 'antecedents': [{'sentenceIndex': 8, 'sta ...

# %%
sample = all_data['s09e03c10t']
sentences = sample['sentences']
annotations = sample['annotations']
for sent in sentences:
    print(sent)
# Out:
# []
# ['这', '个', '叫', '做', '拉', '玛', '泽', '呼', '吸', '可', '以', '帮', '你', '用', '力']
# ['那', '你', '用', '子', '宫', '推', '好', '了']
# ['应', '该', '有', '个', '更', '容', '易', '的', '办', '法', '把', '它', '弄', '下', '来', '的']
# ['是', '的', '这', '不', '过', '就', '是', '个', '物', '理', '学', '问', '题', '罢', '了']
# ['阿', '基', '米', '德', '曾', '经', '说', '了', '"', '给', '我', '一', '根', '足', '够', '长', '的', '的', '杠', '杆', '和', '一', '个', '支', '点', '我', '就', '能', '撬', '动', '地', '球', '"']
# ['我', '们', '只', '需', '要', '找', '点', '原', '材', '料', '把', '这', '个', '杠', '杆', '做', '出', '来', '就', '行', '了']
# ['一', '点', '不', '错', '我', '敢', '打', '赌', '这', '附', '近', '有', '东', '西', '能', '当', '这', '个', '"', '撬', '棍', '"']
# ['让', '我', '找', '找', '"', '撬', '棍', '"', '在', '哪', '呢', '.', '.', '.']
# ['大', '家', '等', '一', '下', '!', '我', '们', '按', '顺', '序', '一', '个', '个', '解', '决', '问', '题', '首', '先', '我', '们', '得', '决', '定', '我', '们', '是', '叫', '它', '杠', '杆', '还', '是', '撬', '棍', '等', '我', '们', '决', '定', '叫', '它', '杠', '杆', '之', '后', '就', '可', '以', '卷', '起', '袖', '子', '.', '.', '.', '而', '不', '是', '衣', '袖', '.', '.', '.']
# ['我', '们', '就', '"', '永', '久', '的', '"', '在', '这', '呆', '着', '吧']

# %%
for item in annotations:
    print(item)
    print(sentences[item['query']['sentenceIndex']][item['query']['startToken']: item['query']['endToken']])
    print()
# Out:
# {'query': {'sentenceIndex': 1, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|3'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['这', '个']
#
# {'query': {'sentenceIndex': 1, 'startToken': 12, 'endToken': 13, 'mention_id': 's09e03c10t|6'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['你']
#
# {'query': {'sentenceIndex': 2, 'startToken': 1, 'endToken': 2, 'mention_id': 's09e03c10t|7'}, 'antecedents': ['Raj']}
# ['你']
#
# {'query': {'sentenceIndex': 2, 'startToken': 3, 'endToken': 5, 'mention_id': 's09e03c10t|11'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['子', '宫']
#
# {'query': {'sentenceIndex': 3, 'startToken': 2, 'endToken': 4, 'mention_id': 's09e03c10t|12'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['有', '个']
#
# {'query': {'sentenceIndex': 3, 'startToken': 5, 'endToken': 13, 'mention_id': 's09e03c10t|13'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['容', '易', '的', '办', '法', '把', '它', '弄']
#
# {'query': {'sentenceIndex': 3, 'startToken': 11, 'endToken': 12, 'mention_id': 's09e03c10t|14'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['它']
#
# {'query': {'sentenceIndex': 4, 'startToken': 2, 'endToken': 3, 'mention_id': 's09e03c10t|15'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['这']
#
# {'query': {'sentenceIndex': 4, 'startToken': 3, 'endToken': 13, 'mention_id': 's09e03c10t|16'}, 'antecedents': [{'sentenceIndex': 4, 'startToken': 2, 'endToken': 3, 'mention_id': 's09e03c10t|17'}]}
# ['不', '过', '就', '是', '个', '物', '理', '学', '问', '题']
#
# {'query': {'sentenceIndex': 4, 'startToken': 7, 'endToken': 13, 'mention_id': 's09e03c10t|19'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['个', '物', '理', '学', '问', '题']
#
# {'query': {'sentenceIndex': 5, 'startToken': 0, 'endToken': 4, 'mention_id': 's09e03c10t|20'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['阿', '基', '米', '德']
#
# {'query': {'sentenceIndex': 5, 'startToken': 10, 'endToken': 25, 'mention_id': 's09e03c10t|21'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['我', '一', '根', '足', '够', '长', '的', '的', '杠', '杆', '和', '一', '个', '支', '点']
#
# {'query': {'sentenceIndex': 5, 'startToken': 10, 'endToken': 11, 'mention_id': 's09e03c10t|22'}, 'antecedents': [{'sentenceIndex': 5, 'startToken': 0, 'endToken': 4, 'mention_id': 's09e03c10t|23'}]}
# ['我']
#
# {'query': {'sentenceIndex': 5, 'startToken': 11, 'endToken': 25, 'mention_id': 's09e03c10t|24'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['一', '根', '足', '够', '长', '的', '的', '杠', '杆', '和', '一', '个', '支', '点']
#
# {'query': {'sentenceIndex': 5, 'startToken': 21, 'endToken': 25, 'mention_id': 's09e03c10t|25'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['一', '个', '支', '点']
#
# {'query': {'sentenceIndex': 5, 'startToken': 25, 'endToken': 26, 'mention_id': 's09e03c10t|30'}, 'antecedents': [{'sentenceIndex': 5, 'startToken': 0, 'endToken': 4, 'mention_id': 's09e03c10t|31'}]}
# ['我']
#
# {'query': {'sentenceIndex': 5, 'startToken': 30, 'endToken': 32, 'mention_id': 's09e03c10t|32'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['地', '球']
#
# {'query': {'sentenceIndex': 6, 'startToken': 2, 'endToken': 3, 'mention_id': 's09e03c10t|33'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['只']
#
# {'query': {'sentenceIndex': 6, 'startToken': 0, 'endToken': 5, 'mention_id': 's09e03c10t|34'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['我', '们', '只', '需', '要']
#
# {'query': {'sentenceIndex': 6, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|35'}, 'antecedents': ['Raj']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 6, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|35'}, 'antecedents': ['Sheldon']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 6, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|35'}, 'antecedents': ['Leonard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 6, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|35'}, 'antecedents': ['Howard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 6, 'startToken': 7, 'endToken': 16, 'mention_id': 's09e03c10t|40'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['原', '材', '料', '把', '这', '个', '杠', '杆', '做']
#
# {'query': {'sentenceIndex': 6, 'startToken': 11, 'endToken': 16, 'mention_id': 's09e03c10t|41'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['这', '个', '杠', '杆', '做']
#
# {'query': {'sentenceIndex': 6, 'startToken': 11, 'endToken': 13, 'mention_id': 's09e03c10t|42'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['这', '个']
#
# {'query': {'sentenceIndex': 7, 'startToken': 4, 'endToken': 6, 'mention_id': 's09e03c10t|43'}, 'antecedents': ['Howard']}
# ['我', '敢']
#
# {'query': {'sentenceIndex': 7, 'startToken': 12, 'endToken': 14, 'mention_id': 's09e03c10t|46'}, 'antecedents': ['null_projection']}
# ['东', '西']
#
# {'query': {'sentenceIndex': 7, 'startToken': 8, 'endToken': 21, 'mention_id': 's09e03c10t|48'}, 'antecedents': ['null_projection']}
# ['这', '附', '近', '有', '东', '西', '能', '当', '这', '个', '"', '撬', '棍']
#
# {'query': {'sentenceIndex': 7, 'startToken': 16, 'endToken': 21, 'mention_id': 's09e03c10t|51'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['这', '个', '"', '撬', '棍']
#
# {'query': {'sentenceIndex': 8, 'startToken': 4, 'endToken': 7, 'mention_id': 's09e03c10t|57'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['"', '撬', '棍']
#
# {'query': {'sentenceIndex': 8, 'startToken': 5, 'endToken': 7, 'mention_id': 's09e03c10t|58'}, 'antecedents': [{'sentenceIndex': 7, 'startToken': 16, 'endToken': 21, 'mention_id': 's09e03c10t|59'}]}
# ['撬', '棍']
#
# {'query': {'sentenceIndex': 9, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|60'}, 'antecedents': ['Howard']}
# ['大', '家']
#
# {'query': {'sentenceIndex': 9, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|60'}, 'antecedents': ['Leonard']}
# ['大', '家']
#
# {'query': {'sentenceIndex': 9, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|60'}, 'antecedents': ['Raj']}
# ['大', '家']
#
# {'query': {'sentenceIndex': 9, 'startToken': 14, 'endToken': 18, 'mention_id': 's09e03c10t|69'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['解', '决', '问', '题']
#
# {'query': {'sentenceIndex': 9, 'startToken': 9, 'endToken': 14, 'mention_id': 's09e03c10t|70'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['顺', '序', '一', '个', '个']
#
# {'query': {'sentenceIndex': 9, 'startToken': 9, 'endToken': 14, 'mention_id': 's09e03c10t|71'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['顺', '序', '一', '个', '个']
#
# {'query': {'sentenceIndex': 9, 'startToken': 6, 'endToken': 22, 'mention_id': 's09e03c10t|72'}, 'antecedents': ['Howard']}
# ['我', '们', '按', '顺', '序', '一', '个', '个', '解', '决', '问', '题', '首', '先', '我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 6, 'endToken': 22, 'mention_id': 's09e03c10t|72'}, 'antecedents': ['Leonard']}
# ['我', '们', '按', '顺', '序', '一', '个', '个', '解', '决', '问', '题', '首', '先', '我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 6, 'endToken': 22, 'mention_id': 's09e03c10t|72'}, 'antecedents': ['Raj']}
# ['我', '们', '按', '顺', '序', '一', '个', '个', '解', '决', '问', '题', '首', '先', '我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 6, 'endToken': 22, 'mention_id': 's09e03c10t|72'}, 'antecedents': ['Sheldon']}
# ['我', '们', '按', '顺', '序', '一', '个', '个', '解', '决', '问', '题', '首', '先', '我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 25, 'endToken': 27, 'mention_id': 's09e03c10t|77'}, 'antecedents': ['Howard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 25, 'endToken': 27, 'mention_id': 's09e03c10t|77'}, 'antecedents': ['Leonard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 25, 'endToken': 27, 'mention_id': 's09e03c10t|77'}, 'antecedents': ['Raj']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 25, 'endToken': 27, 'mention_id': 's09e03c10t|77'}, 'antecedents': ['Sheldon']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 29, 'endToken': 30, 'mention_id': 's09e03c10t|82'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['它']
#
# {'query': {'sentenceIndex': 9, 'startToken': 37, 'endToken': 39, 'mention_id': 's09e03c10t|84'}, 'antecedents': ['Howard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 37, 'endToken': 39, 'mention_id': 's09e03c10t|84'}, 'antecedents': ['Leonard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 37, 'endToken': 39, 'mention_id': 's09e03c10t|84'}, 'antecedents': ['Raj']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 37, 'endToken': 39, 'mention_id': 's09e03c10t|84'}, 'antecedents': ['Sheldon']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 9, 'startToken': 42, 'endToken': 43, 'mention_id': 's09e03c10t|89'}, 'antecedents': [{'sentenceIndex': 9, 'startToken': 29, 'endToken': 30, 'mention_id': 's09e03c10t|90'}]}
# ['它']
#
# {'query': {'sentenceIndex': 9, 'startToken': 52, 'endToken': 62, 'mention_id': 's09e03c10t|102'}, 'antecedents': ['n', 'o', 't', 'P', 'r', 'e', 's', 'e', 'n', 't']}
# ['袖', '子', '.', '.', '.', '而', '不', '是', '衣', '袖']
#
# {'query': {'sentenceIndex': 10, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|104'}, 'antecedents': ['Howard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 10, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|104'}, 'antecedents': ['Leonard']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 10, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|104'}, 'antecedents': ['Raj']}
# ['我', '们']
#
# {'query': {'sentenceIndex': 10, 'startToken': 0, 'endToken': 2, 'mention_id': 's09e03c10t|104'}, 'antecedents': ['Sheldon']}
# ['我', '们']
